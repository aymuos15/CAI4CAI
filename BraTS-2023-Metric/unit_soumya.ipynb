# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

from proposed import metric
from soumya import dice, get_LesionWiseResults

# %%
pred = np.zeros((55, 55))
gt   = np.zeros((55, 55))

gt[5:15, 5:15] = 1
gt[5:15, 25:35] = 1
pred[5:15, 10:30] = 1

gt_display = gt*2

fig, ax = plt.subplots(1, 3, figsize=(10, 5))
ax[0].imshow(pred, cmap='gray')
ax[0].set_title('Prediction')

ax[1].imshow(gt_display, cmap='gray')
ax[1].set_title('Ground Truth')

im2 = ax[2].imshow(pred + gt_display, cmap='rainbow')
ax[2].set_title('Overlay (Prediction + Ground Truth)')

legend_elements = [Patch(facecolor='purple', edgecolor='black', label='TN'),
                   Patch(facecolor='turquoise', edgecolor='black', label='FP'),
                   Patch(facecolor='yellow', edgecolor='black', label='FN'),
                   Patch(facecolor='red', edgecolor='black', label='TP')]

# ax[2].legend(handles=legend_elements, loc='upper left')
ax[2].legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1.02, 1))

plt.show()

get_LesionWiseResults(pred, gt, 'BraTS-MET')
print('Proposed Score:', metric(pred, gt))
print('Normal Dice:', dice(pred, gt))
# Out:
# Unique GT Components before dilation: [0 1 2]
# Unique GT Components after dilation: [0 1 2]
# Miccai Dice: 0.3333333333333333
# Proposed Score: 0.5
# Normal Dice: 0.5

# %%
pred = np.zeros((55, 55))
gt   = np.zeros((55, 55))

gt[5:15, 5:15] = 1
gt[5:15, 16:35] = 1
pred[5:15, 10:30] = 1

gt_display = gt*2

fig, ax = plt.subplots(1, 3, figsize=(10, 5))
ax[0].imshow(pred, cmap='gray')
ax[0].set_title('Prediction')

ax[1].imshow(gt_display, cmap='gray')
ax[1].set_title('Ground Truth')

im2 = ax[2].imshow(pred + gt_display, cmap='rainbow')
ax[2].set_title('Overlay (Prediction + Ground Truth)')

legend_elements = [Patch(facecolor='purple', edgecolor='black', label='TN'),
                   Patch(facecolor='turquoise', edgecolor='black', label='FP'),
                   Patch(facecolor='yellow', edgecolor='black', label='FN'),
                   Patch(facecolor='red', edgecolor='black', label='TP')]

# ax[2].legend(handles=legend_elements, loc='upper left')
ax[2].legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1.02, 1))

plt.show()

get_LesionWiseResults(pred, gt, 'BraTS-MET')
print('Proposed Score:', metric(pred, gt))
print('Normal Dice:', dice(pred, gt))
# Out:
# Unique GT Components before dilation: [0 1 2]
# Unique GT Components after dilation: [0 1]
# Miccai Dice: 0.7755102040816326
# Proposed Score: 0.7755102040816326
# Normal Dice: 0.7755102040816326

# %%
pred = np.zeros((55, 55))
gt   = np.zeros((55, 55))

pred[5:15, 5:15] = 1
pred[5:15, 25:35] = 1
gt[5:15, 10:30] = 1

gt_display = gt*2

fig, ax = plt.subplots(1, 3, figsize=(10, 5))
ax[0].imshow(pred, cmap='gray')
ax[0].set_title('Prediction')

ax[1].imshow(gt_display, cmap='gray')
ax[1].set_title('Ground Truth')

im2 = ax[2].imshow(pred + gt_display, cmap='rainbow')
ax[2].set_title('Overlay (Prediction + Ground Truth)')

legend_elements = [Patch(facecolor='purple', edgecolor='black', label='TN'),
                   Patch(facecolor='turquoise', edgecolor='black', label='FP'),
                   Patch(facecolor='yellow', edgecolor='black', label='FN'),
                   Patch(facecolor='red', edgecolor='black', label='TP')]

# ax[2].legend(handles=legend_elements, loc='upper left')
ax[2].legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1.02, 1))

plt.show()

get_LesionWiseResults(pred, gt, 'BraTS-MET')
print('Proposed Score:', metric(pred, gt))
print('Normal Dice:', dice(pred, gt))
# Out:
# Unique GT Components before dilation: [0 1]
# Unique GT Components after dilation: [0 1]
# Miccai Dice: 0.5
# Proposed Score: 0.5
# Normal Dice: 0.5

# %%
pred = np.zeros((55, 55))
gt   = np.zeros((55, 55))

gt[35:45, 5:15] = 1
gt[35:45, 25:35] = 1
pred[35:45, 10:30] = 1

pred[5:15, 5:15] = 1
pred[5:15, 25:35] = 1
gt[5:15, 10:30] = 1

gt_display = gt*2

fig, ax = plt.subplots(1, 3, figsize=(10, 5))
ax[0].imshow(pred, cmap='gray')
ax[0].set_title('Prediction')

ax[1].imshow(gt_display, cmap='gray')
ax[1].set_title('Ground Truth')

im2 = ax[2].imshow(pred + gt_display, cmap='rainbow')
ax[2].set_title('Overlay (Prediction + Ground Truth)')

legend_elements = [Patch(facecolor='purple', edgecolor='black', label='TN'),
                   Patch(facecolor='turquoise', edgecolor='black', label='FP'),
                   Patch(facecolor='yellow', edgecolor='black', label='FN'),
                   Patch(facecolor='red', edgecolor='black', label='TP')]

# ax[2].legend(handles=legend_elements, loc='upper left')
ax[2].legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1.02, 1))

plt.show()

get_LesionWiseResults(pred, gt, 'BraTS-MET')
print('Proposed Score:', metric(pred, gt))
print('Normal Dice:', dice(pred, gt))
# Out:
# Unique GT Components before dilation: [0 1 2 3]
# Unique GT Components after dilation: [0 1 2 3]
# Miccai Dice: 0.38888888888888884
# Proposed Score: 0.5
# Normal Dice: 0.5
