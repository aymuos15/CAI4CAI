# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# %%
from soumya import get_LesionWiseResults
from proposed import metric
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 from soumya import get_LesionWiseResults
# ----> 2 from proposed import metric
#
# File ~/CAI4CAI/BraTS-2023-Metrics/proposed.py:4
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 from miccai_dice import dice
#       6 def find_overlapping_components(prediction_cc, gt_cc):
#       7     overlapping_components = {}
#
# ModuleNotFoundError: No module named 'miccai_dice'

# %%
pred = np.zeros((55, 55))
gt   = np.zeros((55, 55))

gt[5:15, 5:15] = 1
gt[5:15, 25:35] = 1
pred[5:15, 10:30] = 1

gt_display = gt*2

fig, ax = plt.subplots(1, 3, figsize=(10, 5))
ax[0].imshow(pred, cmap='gray')
ax[0].set_title('Prediction')

ax[1].imshow(gt_display, cmap='gray')
ax[1].set_title('Ground Truth')

im2 = ax[2].imshow(pred + gt_display, cmap='rainbow')
ax[2].set_title('Overlay (Prediction + Ground Truth)')

legend_elements = [Patch(facecolor='purple', edgecolor='black', label='TN'),
                   Patch(facecolor='turquoise', edgecolor='black', label='FP'),
                   Patch(facecolor='yellow', edgecolor='black', label='FN'),
                   Patch(facecolor='red', edgecolor='black', label='TP')]

# ax[2].legend(handles=legend_elements, loc='upper left')
ax[2].legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1.02, 1))

plt.show()

# %%
print(get_LesionWiseResults(pred, gt, 'BraTS-MET'))
print(metric(pred, gt))
# Out:
# original Unique GT: [0 1 2]
# Unique GT: [0 1]
# GT: 1
# original Unique GT: [0 1 2]
# Unique GT: [0 1]
# GT: 2
#   Labels  Num_TP  Num_FP  Num_FN  Legacy_Dice  LesionWise_Score_Dice
# 0     WT     0.0     0.0     0.0          0.5               0.333333
# Normal Overlap Metrics:
# [{'GT': [1, 2], 'Pred': 1, 'Dice': 0.5}]
#        GT  Pred  Dice
# 2  [1, 2]     1   0.5
# 0.5

# %%
pred = np.zeros((55, 55))
gt   = np.zeros((55, 55))

pred[5:15, 5:15] = 1
pred[5:15, 25:35] = 1
gt[5:15, 10:30] = 1

gt_display = gt*2

fig, ax = plt.subplots(1, 3, figsize=(10, 5))
ax[0].imshow(pred, cmap='gray')
ax[0].set_title('Prediction')

ax[1].imshow(gt_display, cmap='gray')
ax[1].set_title('Ground Truth')

im2 = ax[2].imshow(pred + gt_display, cmap='rainbow')
ax[2].set_title('Overlay (Prediction + Ground Truth)')

legend_elements = [Patch(facecolor='purple', edgecolor='black', label='TN'),
                   Patch(facecolor='turquoise', edgecolor='black', label='FP'),
                   Patch(facecolor='yellow', edgecolor='black', label='FN'),
                   Patch(facecolor='red', edgecolor='black', label='TP')]

# ax[2].legend(handles=legend_elements, loc='upper left')
ax[2].legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1.02, 1))

plt.show()

# %%
print(get_LesionWiseResults(pred, gt, 'BraTS-MET'))
print(metric(pred, gt))
# Out:
# original Unique GT: [0 1]
# Unique GT: [0 1]
# GT: 1
#   Labels  Num_TP  Num_FP  Num_FN  Legacy_Dice  LesionWise_Score_Dice
# 0     WT     0.0     0.0     0.0          0.5                    0.5
# Inverted Overlap Metrics:
# [{'GT': 1, 'Pred': [1, 2], 'Dice': 0.5}]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 print(get_LesionWiseResults(pred, gt, 'BraTS-MET'))
# ----> 2 print(metric(pred, gt))
#
# File ~/CAI4CAI/BraTS-2023-Metrics/proposed.py:162, in metric(pred, gt)
#     158 pred_label_cc = cc3d.connected_components(pred)
#     160 overlapping_components = find_overlapping_components(pred_label_cc, gt_label_cc)
# --> 162 metrics, fp = collect_metrics(pred_label_cc, gt_label_cc, overlapping_components)
#     164 return lesion_wise_metric(metrics, fp)
#
# File ~/CAI4CAI/BraTS-2023-Metrics/proposed.py:137, in collect_metrics(pred_label_cc, gt_label_cc, overlapping_components)
#     134     if isinstance(row['GT'], int):
#     135         pred_int.append(row['Pred'])
# --> 137 common_elements = set(pred_list).intersection(set(pred_int))
#     139 for index, row in final_metrics_df.iterrows():
#     140     if row['Pred'] in common_elements and isinstance(row['GT'], int):
#
# TypeError: unhashable type: 'list'
